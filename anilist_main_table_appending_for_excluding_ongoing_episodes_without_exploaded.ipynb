# %% [markdown]
# <a href="https://colab.research.google.com/github/St4rLighr/anime_forecasting/blob/colab_codes/anilist_main_table_appending_for_excluding_ongoing_episodes_without_exploaded.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#first we import libraries to use
import pandas as pd
from google.colab import auth
import pandas_gbq

# Will collect credentials
auth.authenticate_user()

# %%
# Query Bigquery
query_1 = "SELECT * FROM `anime-forecasting.anilist_api_batch1.dropped_eps_rank_bq_ver`"
query_2 = "SELECT * FROM `anime-forecasting.anilist_api_batch4.batch4_cleaned`"
query_3 = "SELECT * FROM `anime-forecasting.anilist_api_batch5.batch5_anime_dataset_excludes_eps_ranks`"
query_4 = "SELECT * FROM `anime-forecasting.anilist_api_batch6.batch6_dataset_excludes_eps_ranks`"
query_5 = "SELECT * FROM `anime-forecasting.anilist_api_batch7.batch7_dataset_excludes_eps_rank`"
query_6 = "SELECT * FROM `anime-forecasting.anilist_api_batch8.batch8_dropped_eps_rank_bq_ver`"


table_1 = pandas_gbq.read_gbq(query_1, project_id="anime-forecasting")
table_2 = pandas_gbq.read_gbq(query_2, project_id="anime-forecasting")
table_3 = pandas_gbq.read_gbq(query_3, project_id="anime-forecasting")
table_4 = pandas_gbq.read_gbq(query_4, project_id="anime-forecasting")
table_5 = pandas_gbq.read_gbq(query_5, project_id="anime-forecasting")
table_6 = pandas_gbq.read_gbq(query_6, project_id="anime-forecasting")
# Out:
# Downloading: 100%|██████████|
# Downloading: 100%|██████████|
# Downloading: 100%|██████████|
# Downloading: 100%|██████████|
# Downloading: 100%|██████████|
# Downloading: 100%|██████████|

# %% [markdown]
# ## Checking for nulls in all table

# %%
table_1.isnull().sum() #drop type column, rename site to externalsites
# Out:
# id                           0
# idMal                        0
# title                        0
# format                       0
# episodes                     0
# duration                     0
# status                       0
# startDay                     0
# startMonth                   0
# startYear                    0
# meanScore                    0
# popularity                   0
# favourites                   0
# genres                       0
# site                         0
# type                         0
# scoreDistribution_amount     0
# scoreDistribution_score      0
# statusDistribution_score     0
# statusDistribution_status    0
# rankings_context             0
# tags                         0
# start_date                   0
# dtype: int64

# %%
table_2.isnull().sum()
# Out:
# id                           0
# idMal                        0
# title                        0
# format                       0
# episodes                     0
# duration                     0
# status                       0
# startDay                     0
# startMonth                   0
# meanScore                    0
# popularity                   0
# favourites                   0
# genres                       0
# scoreDistribution_amount     0
# scoreDistribution_score      0
# statusDistribution_score     0
# statusDistribution_status    0
# rankings_context             0
# tags                         0
# external_sites               0
# startYear                    0
# start_date                   0
# dtype: int64

# %%
table_3.isnull().sum() #drop site, type,id_1, idMal_1 columns, drop null sites, rename sites to external_sites
# Out:
# id                            0
# idMal                         0
# title                         0
# format                        0
# episodes                      0
# duration                      0
# status                        0
# startDay                      0
# startMonth                    0
# startYear                     0
# meanScore                     0
# popularity                    0
# favourites                    0
# genres                        0
# site                          0
# type                          0
# scoreDistribution_amount      0
# scoreDistribution_score       0
# statusDistribution_score      0
# statusDistribution_status     0
# rankings_context              0
# tags                          0
# id_1                         10
# idMal_1                      10
# sites                        10
# start_date                    0
# dtype: int64

# %%
table_4.isnull().sum()  #drop site,type, external_id columns, drop null external_sites
# Out:
# id                           0
# idMal                        0
# title                        0
# format                       0
# episodes                     0
# duration                     0
# status                       0
# startDay                     0
# startMonth                   0
# startYear                    0
# meanScore                    0
# popularity                   0
# favourites                   0
# genres                       0
# site                         0
# type                         0
# scoreDistribution_amount     0
# scoreDistribution_score      0
# statusDistribution_score     0
# statusDistribution_status    0
# rankings_context             0
# tags                         0
# external_id                  2
# external_sites               2
# start_date                   0
# dtype: int64

# %%
table_5.isnull().sum() #drop site,type,id_1, idMal_1 columns, drop null sites, rename sites to external_sites
# Out:
# id                           0
# idMal                        0
# title                        0
# format                       0
# episodes                     0
# duration                     0
# status                       0
# startDay                     0
# startMonth                   0
# startYear                    0
# meanScore                    0
# popularity                   0
# favourites                   0
# genres                       0
# site                         0
# type                         0
# scoreDistribution_amount     0
# scoreDistribution_score      0
# statusDistribution_score     0
# statusDistribution_status    0
# rankings_context             0
# tags                         0
# id_1                         1
# idMal_1                      1
# sites                        1
# start_date                   0
# dtype: int64

# %%
table_6.isnull().sum()
# Out:
# id                           0
# idMal                        0
# title                        0
# format                       0
# episodes                     0
# duration                     0
# status                       0
# startDay                     0
# startMonth                   0
# startYear                    0
# meanScore                    0
# popularity                   0
# favourites                   0
# genres                       0
# scoreDistribution_amount     0
# scoreDistribution_score      0
# statusDistribution_score     0
# statusDistribution_status    0
# rankings_context             0
# tags                         0
# external_sites               0
# start_date                   0
# dtype: int64

# %% [markdown]
# ## Renaming and dropping columns

# %% [markdown]
# ### Table 1
#
#
#
#
# To Do
#
# drop type column
#
# rename site to externalsites

# %%
table_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1471 entries, 0 to 1470
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1471 non-null   Int64
#  1   idMal                      1471 non-null   Int64
#  2   title                      1471 non-null   object
#  3   format                     1471 non-null   object
#  4   episodes                   1468 non-null   Int64
#  5   duration                   1471 non-null   Int64
#  6   status                     1471 non-null   object
#  7   startDay                   1471 non-null   Int64
#  8   startMonth                 1471 non-null   Int64
#  9   startYear                  1471 non-null   Int64
#  10  meanScore                  1471 non-null   float64
#  11  popularity                 1471 non-null   Int64
#  12  favourites                 1471 non-null   Int64
# ...

# %%
# Drop type column
table_1 = table_1.drop(['type'], axis=1)

# %%
table_1['external_sites'] = table_1['site']

# %%
table_1 = table_1.drop(['site'], axis=1)

# %%
table_1.isnull().sum()
# Out:
# id                           0
# idMal                        0
# title                        0
# format                       0
# episodes                     0
# duration                     0
# status                       0
# startDay                     0
# startMonth                   0
# startYear                    0
# meanScore                    0
# popularity                   0
# favourites                   0
# genres                       0
# scoreDistribution_amount     0
# scoreDistribution_score      0
# statusDistribution_score     0
# statusDistribution_status    0
# rankings_context             0
# tags                         0
# start_date                   0
# external_sites               0
# dtype: int64

# %% [markdown]
# ### Table 2
#
#
#
# To Do
#
# drop null titles, idMal, duration, startyear, meanscore, external_sites
#
# drop site, type, isdisabled, rankings (except ranks and context) and external_id columns, avgscore,
#
# rename starYear to startYear
#
# filter by TV
#
# create start date column

# %%
table_2.isnull().sum()
# Out:
# id                           0
# idMal                        0
# title                        0
# format                       0
# episodes                     0
# duration                     0
# status                       0
# startDay                     0
# startMonth                   0
# meanScore                    0
# popularity                   0
# favourites                   0
# genres                       0
# scoreDistribution_amount     0
# scoreDistribution_score      0
# statusDistribution_score     0
# statusDistribution_status    0
# rankings_context             0
# tags                         0
# external_sites               0
# startYear                    0
# start_date                   0
# dtype: int64

# %% [markdown]
# ### Table 3
#
#
# To Do
#
# drop id_1, idMal_1, site, type columns
#
# drop null sites
#
# rename sites to external_sites

# %%
table_3 = table_3.drop(['id_1','idMal_1','site','type'], axis=1)

# %%
table_3.dropna(subset="sites",inplace=True)

# %%
table_3['external_sites'] = table_3['sites']

# %%
table_3 = table_3.drop(['sites'], axis=1)

# %%
table_3.isnull().sum()
# Out:
# id                           0
# idMal                        0
# title                        0
# format                       0
# episodes                     0
# duration                     0
# status                       0
# startDay                     0
# startMonth                   0
# startYear                    0
# meanScore                    0
# popularity                   0
# favourites                   0
# genres                       0
# scoreDistribution_amount     0
# scoreDistribution_score      0
# statusDistribution_score     0
# statusDistribution_status    0
# rankings_context             0
# tags                         0
# start_date                   0
# external_sites               0
# dtype: int64

# %% [markdown]
# ### Table 4
#
#
# To Do
#
# drop site,type, external_id columns
#
# drop null external_sites

# %%
table_4 = table_4.drop(['site','type','external_id'], axis=1)

# %%
table_4.dropna(subset="external_sites",inplace=True)

# %%
table_4.isnull().sum()
# Out:
# id                           0
# idMal                        0
# title                        0
# format                       0
# episodes                     0
# duration                     0
# status                       0
# startDay                     0
# startMonth                   0
# startYear                    0
# meanScore                    0
# popularity                   0
# favourites                   0
# genres                       0
# scoreDistribution_amount     0
# scoreDistribution_score      0
# statusDistribution_score     0
# statusDistribution_status    0
# rankings_context             0
# tags                         0
# external_sites               0
# start_date                   0
# dtype: int64

# %% [markdown]
# ### Table 5
#
#
# To Do
#
# drop site,type,id_1, idMal_1 columns
#
# drop null sites
#
# rename sites to external_sites

# %%
table_5 = table_5.drop(['site','type','id_1','idMal_1'], axis=1)

# %%
table_5['external_sites'] = table_5['sites']

# %%
table_5 = table_5.drop(['sites'], axis=1)

# %%
table_5.dropna(subset="external_sites",inplace=True)

# %%
table_5.isnull().sum()
# Out:
# id                           0
# idMal                        0
# title                        0
# format                       0
# episodes                     0
# duration                     0
# status                       0
# startDay                     0
# startMonth                   0
# startYear                    0
# meanScore                    0
# popularity                   0
# favourites                   0
# genres                       0
# scoreDistribution_amount     0
# scoreDistribution_score      0
# statusDistribution_score     0
# statusDistribution_status    0
# rankings_context             0
# tags                         0
# start_date                   0
# external_sites               0
# dtype: int64

# %% [markdown]
# ### Table 6
#
#
#
# To Do

# %%
table_6.dropna(subset="tags",inplace=True)

# %%
table_6.isnull().sum()
# Out:
# id                             0
# idMal                          0
# title                          0
# format                         0
# episodes                     771
# duration                       0
# status                         0
# startDay                       0
# startMonth                     0
# startYear                      0
# meanScore                      0
# popularity                     0
# favourites                     0
# genres                         0
# scoreDistribution_amount       0
# scoreDistribution_score        0
# statusDistribution_score       0
# statusDistribution_status      0
# rankings_context               0
# tags                           0
# external_sites                 0
# start_date                     0
# dtype: int64

# %% [markdown]
# ## Appending table

# %%
tables = [table_1, table_2, table_3, table_4, table_5, table_6]
main_table = pd.concat(tables, ignore_index=True)

# %%
main_table
# Out:
#           id  idMal                             title format  episodes  \
# 0        721    721                     Princess Tutu     TV        38
# 1        754    754                    The Snow Queen     TV        36
# 2        961    961                    Virtua Fighter     TV        35
# 3       1018   1018                 Orphen 2: Revenge     TV        23
# 4       1137   1137                            Shinzo     TV        32
# ...      ...    ...                               ...    ...       ...
# 2543  162209  54638  KAWAGOE BOYS SING -Now or Never-     TV        12
# 2544  155419  53262                 Stardust Telepath     TV        12
# 2545  162803  54743      Dead Mount Death Play Part 2     TV        12
# 2546  162670  55644        Dr. STONE New World Part 2     TV        11
# 2547  161645  54492            The Apothecary Diaries     TV        24
#
#       duration    status  startDay  startMonth  startYear  ...  favourites  \
# ...

# %%
#check for duplicates
main_table.duplicated().sum()
# Out:
# 0

# %%
# main_table = main_table.drop_duplicates()

# %%
main_table.info()


#isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2538 entries, 0 to 2537
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         2538 non-null   Int64
#  1   idMal                      2538 non-null   Int64
#  2   title                      2538 non-null   object
#  3   format                     2538 non-null   object
#  4   episodes                   2538 non-null   Int64
#  5   duration                   2538 non-null   Int64
#  6   status                     2538 non-null   object
#  7   startDay                   2538 non-null   Int64
#  8   startMonth                 2538 non-null   Int64
#  9   startYear                  2538 non-null   Int64
#  10  meanScore                  2538 non-null   float64
#  11  popularity                 2538 non-null   Int64
#  12  favourites                 2538 non-null   Int64
# ...

# %%
main_table.isnull().sum()
# Out:
# id                           0
# idMal                        0
# title                        0
# format                       0
# episodes                     0
# duration                     0
# status                       0
# startDay                     0
# startMonth                   0
# startYear                    0
# meanScore                    0
# popularity                   0
# favourites                   0
# genres                       0
# scoreDistribution_amount     0
# scoreDistribution_score      0
# statusDistribution_score     0
# statusDistribution_status    0
# rankings_context             0
# tags                         0
# start_date                   0
# external_sites               0
# dtype: int64

# %%
main_table.to_csv("anilist_excluding_eps_main_table.csv", index=False)
